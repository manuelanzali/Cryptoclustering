# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
scaled_data = StandardScaler().fit_transform(df_market_data.select_dtypes(include=['float64', 'int64']))

# %%
# Create a DataFrame with the scaled data
scaled_data_df = pd.DataFrame(scaled_data,
                              columns = df_market_data.select_dtypes(include=['float64', 'int64']).columns)

# Copy the crypto names from the original DataFrame
scaled_data_df["coin_id"] = df_market_data.index

# Set the coin_id column as index
scaled_data_df.set_index("coin_id", inplace=True)

# Display the scaled DataFrame
scaled_data_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values from 1 to 11

k = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
for i in k:
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
    k_model = KMeans(n_clusters=i, random_state=1)
# 2. Fit the model to the data using `df_market_data_scaled`
    k_model.fit(scaled_data_df)
# 3. Append the model.inertia_ to the inertia list
    inertia.append(k_model.inertia_)
    print(f"for k={i}, we have an inertia of {k_model.inertia_}")
# Out:
# for k=1, we have an inertia of 287.0
# for k=2, we have an inertia of 212.1233420748626
# for k=3, we have an inertia of 165.13675233446816
# for k=4, we have an inertia of 79.02243535120977
# for k=5, we have an inertia of 66.41305075939437
# for k=6, we have an inertia of 61.6340881106822
# for k=7, we have an inertia of 46.074467441030215
# for k=8, we have an inertia of 43.39269411734827
# for k=9, we have an inertia of 32.91322265971525
# for k=10, we have an inertia of 30.46911129327036
# c:\Users\bryan\anaconda3\envs\dev\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_df = pd.DataFrame({"k": k, "inertia": inertia})

# Create a DataFrame with the data to plot the Elbow curve
elbow_df.head()
# Out:
#    k     inertia
# 0  1  287.000000
# 1  2  212.123342
# 2  3  165.136752
# 3  4   79.022435
# 4  5   66.413051

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.

elbow_plot_original = elbow_df.hvplot.line(x="k", y="inertia")
elbow_plot_original
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** The best value for 'k' is 4.

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4, random_state=1)

# %%
# Fit the K-Means model using the scaled DataFrame
model.fit(scaled_data_df)
# Out:
# c:\Users\bryan\anaconda3\envs\dev\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame
k_4 = model.predict(scaled_data_df)

# Print the resulting array of cluster values.
print(k_4)
# Out:
# [2 2 0 0 2 2 2 2 2 0 0 0 0 2 0 2 0 0 2 0 0 2 0 0 0 0 0 0 2 0 0 0 3 2 0 0 1
#  0 0 0 0]

# %%
# Create a copy of the scaled DataFrame
scaled_data_df = scaled_data_df.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters
scaled_data_df['cluster'] = k_4

# Display the copy of the scaled DataFrame
scaled_data_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.

# Reset the index to make 'coin_id' a column
#scaled_data_df = scaled_data_df.reset_index()

cluster_plot_original = scaled_data_df.hvplot.scatter(
    x= "price_change_percentage_24h",
    y= "price_change_percentage_7d",
    by= "cluster",
    hover_cols= ["coin_id"]
)
cluster_plot_original
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled DataFrame
# down to three principal components.
scaled_pca = pca.fit_transform(scaled_data_df)

# View the scaled PCA data
scaled_pca[:5]
# Out:
# array([[ 0.44890795,  1.24537573,  0.8506404 ],
#        [ 0.49536709,  0.899823  ,  1.31755943],
#        [-0.81884571, -0.07189909, -0.69501507],
#        [-0.84035711, -0.08005407, -0.54435952],
#        [ 0.81324004,  2.66952035,  1.64332113]])

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.
pca.explained_variance_ratio_
# Out:
# array([0.34871677, 0.31363391, 0.22627118])

# %%
# Calculate the total explained variance of the three principal components
total_explained_variance = sum(pca.explained_variance_ratio_)
total_explained_variance
# Out:
# 0.8886218549859446

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** The total explained variance is 0.8886218549859446.

# %%
# Create a new DataFrame with the PCA data.
scaled_pca_df = pd.DataFrame(
    scaled_pca,
    columns=["PC1", "PC2", "PC3"]
)

# Copy the crypto names from the original scaled DataFrame
scaled_pca_df["coin_id"] = scaled_data_df.index

# Set the coin_id column as index
scaled_pca_df.set_index("coin_id", inplace=True)

# Display the scaled PCA DataFrame
scaled_pca_df
# Out:
#                            PC1       PC2       PC3
# coin_id
# bitcoin               0.448908  1.245376  0.850640
# ethereum              0.495367  0.899823  1.317559
# tether               -0.818846 -0.071899 -0.695015
# ripple               -0.840357 -0.080054 -0.544360
# bitcoin-cash          0.813240  2.669520  1.643321
# binancecoin           0.822871  1.682096  0.905203
# chainlink             0.913868  1.128684  2.730038
# cardano               0.811102  1.113378  1.598655
# litecoin              0.258728  0.946884  1.103560
# bitcoin-cash-sv      -1.003921  0.119410 -0.278564
# crypto-com-chain     -1.363289 -1.245349 -0.950712
# usd-coin             -0.830643 -0.077047 -0.707661
# eos                  -1.135458 -0.171401 -0.441569
# monero                2.084978  2.688979  0.776469
# tron                 -0.633198  0.016911 -0.249426
# tezos                -0.161908  0.310904  1.818521
# okb                  -0.996987 -1.292574 -0.793701
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
for i in k:
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
    k_model = KMeans(n_clusters=i, random_state=1)
# 2. Fit the model to the data using `df_market_data_pca`
    k_model.fit(scaled_pca_df)
# 3. Append the model.inertia_ to the inertia list
    inertia.append(k_model.inertia_)
    print(f"for k={i}, we have an inertia of {k_model.inertia_}")
# Out:
# for k=1, we have an inertia of 290.6226939879642
# for k=2, we have an inertia of 207.30743902517526
# for k=3, we have an inertia of 123.12695056327829
# for k=4, we have an inertia of 44.130602253217134
# for k=5, we have an inertia of 33.2174272551524
# for k=6, we have an inertia of 23.374713031741738
# for k=7, we have an inertia of 20.943077394523403
# for k=8, we have an inertia of 18.666961001043948
# for k=9, we have an inertia of 13.640110276427894
# for k=10, we have an inertia of 10.287149461797636
# c:\Users\bryan\anaconda3\envs\dev\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
pca_elbow_data = {"k": k, "inertia": inertia}

# Create a DataFrame with the data to plot the Elbow curve
pca_df_elbow = pd.DataFrame(pca_elbow_data)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.

elbow_plot_pca = pca_df_elbow.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xticks=k
)
elbow_plot_pca
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** The best value for 'k' is 4 when using the PCA data.
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** This does not differ from the best k value found using the original data.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4, random_state=0)

# %%
# Fit the K-Means model using the PCA data
model.fit(scaled_pca_df)
# Out:
# c:\Users\bryan\anaconda3\envs\dev\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame
pca_k_4 = model.predict(scaled_pca_df)

# Print the resulting array of cluster values.
print(pca_k_4)
# Out:
# [2 2 0 0 2 2 2 2 2 0 0 0 0 2 0 2 0 0 2 0 0 2 0 0 0 0 0 0 2 0 0 0 1 2 0 0 3
#  0 0 0 0]

# %%
# Create a copy of the scaled PCA DataFrame
scaled_pca_predictions_df = scaled_pca_df.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters
scaled_pca_predictions_df["predicted clusters"] = pca_k_4

# Display the copy of the scaled PCA DataFrame
scaled_pca_predictions_df.head()
# Out:
#                    PC1       PC2       PC3  predicted clusters
# coin_id
# bitcoin       0.448908  1.245376  0.850640                   2
# ethereum      0.495367  0.899823  1.317559                   2
# tether       -0.818846 -0.071899 -0.695015                   0
# ripple       -0.840357 -0.080054 -0.544360                   0
# bitcoin-cash  0.813240  2.669520  1.643321                   2

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.

cluster_plot_pca = scaled_pca_predictions_df.hvplot.scatter(
    x= "PC1",
    y= "PC2",
    by= "predicted clusters",
    hover_cols= ["coin_id"]
)
cluster_plot_pca
# Out:
# :NdOverlay   [predicted clusters]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves
composite_plot_elbow = elbow_plot_original + elbow_plot_pca
composite_plot_elbow
# Out:
# :Layout
#    .Curve.I  :Curve   [k]   (inertia)
#    .Curve.II :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters
composite_plot_clusters = cluster_plot_original + cluster_plot_pca
composite_plot_clusters
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [cluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [predicted clusters]
#       :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** The impact of using fewer features to cluster the data using K-Means is that the inertia changes. In the left figure, there is more distance between each data point in each cluster, whereas in the right figure there is less distance between each data point in each cluster. This shows us that when we cluster the data using K-Means, the inertia is higher than when we use more features to cluster the data.
